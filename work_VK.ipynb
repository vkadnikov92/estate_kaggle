# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import *
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
plt.rcParams['figure.dpi'] = 100
plt.style.use('ggplot')
from sklearn.preprocessing import StandardScaler, RobustScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
import xgboost

# %%
df = pd.read_csv("data/train.csv")
test = pd.read_csv('data/test.csv')
subm_df=pd.concat([df,test],axis=0)
y_train=df['SalePrice']

# %%
df.shape, test.shape, subm_df.shape
# Out:
# ((1460, 81), (1459, 80), (2919, 81))

# %%
subm_df.drop('SalePrice', axis=1, inplace=True)

# %%
subm_df.shape
# Out:
# (2919, 80)

# %%
subm_cols = subm_df.columns.to_list()
subm_cols[40:]
# len(subm_cols)
# Out:
# ['HeatingQC',
#  'CentralAir',
#  'Electrical',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'KitchenQual',
#  'TotRmsAbvGrd',
#  'Functional',
#  'Fireplaces',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageCars',
#  'GarageArea',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'MiscVal',
#  'MoSold',
#  'YrSold',
#  'SaleType',
#  'SaleCondition']

# %%
subm_df.shape
# Out:
# (2919, 80)

# %%
def col_analytics(col):
    print(f'Число NaN: {subm_df[col].isna().sum()}')
    print(f'Число уникальный значений: {subm_df[col].nunique()}')
    print(subm_df[col].value_counts())
    sns.histplot(subm_df[col])

# %% [markdown]
# #### Форматирование колонок

# %%
# col_analytics('FireplaceQu')

# %%
col_2_encoding = ['GarageType', 'GarageFinish', 'MoSold', 'YrSold']
# col_2_reshape_2encoding = ['Fireplaces', 'FireplaceQu', 'HeatingQC', 'BsmtFullBath', 'KitchenQual', 
# 'GarageCars', 'PavedDrive', 'OpenPorchSF', 'WoodDeckSF', 'HalfBath'] # done
col_2_normalize = ['FullBath', '1stFlrSF', 'GrLivArea', 'TotRmsAbvGrd', 'GarageYrBlt', 'GarageArea',
                   'BedroomAbvGr']
col_2_delete = ['LowQualFinSF', '2ndFlrSF', 'BsmtHalfBath', 'Functional', 'WoodDeckSF', 
                'PoolArea', 'PoolQC', 'Fence', 'MiscFeature', 'MiscVal', 'CentralAir', 'Electrical', 'GarageQual', 
                'EnclosedPorch','3SsnPorch', 'ScreenPorch', 'KitchenAbvGr', 'SaleType']

# %%
# Перекодирование колонки 'Fireplaces' на 1 или 0
subm_df['Fireplaces'] = subm_df['Fireplaces'].apply(lambda x: 1 if x > 0 else 0)
# Перекодирование колонки 'FireplaceQu' на 1 или 0
subm_df['FireplaceQu'] = subm_df['FireplaceQu'].apply(lambda x: 1 if x in ['Gd', 'Ex'] else 0)
# Перекодирование колонки 'HeatingQC' на 1 или 0
subm_df['HeatingQC'] = subm_df['HeatingQC'].apply(lambda x: 1 if x in ['Ex'] else 0)
# Перекодирование колонки 'HeatingQC' на 1 или 0
subm_df['BsmtFullBath'] = subm_df['BsmtFullBath'].apply(lambda x: 1 if x in [1, 2] else 0)
# Перекодирование колонки 'KitchenQual' на 1 или 0
subm_df['KitchenQual'] = subm_df['KitchenQual'].apply(lambda x: 1 if x in ['Gd', 'Ex'] else 0)


# Оставить только значения 'Attchd' и 'Detchd', остальные заменить на 'Other'
garage_mapping = {'Attchd': 'Attchd', 'Detchd': 'Detchd', 'BuiltIn': 'Other', 'Basment': 'Other',
    '2Types': 'Other', 'CarPort': 'Other'}
subm_df['GarageType'] = subm_df['GarageType'].map(garage_mapping)

# Перекодирование колонки 'GarageCars' на 1 или 0
subm_df['GarageCars'] = subm_df['GarageCars'].apply(lambda x: 1 if x == 1 else 2 if x == 2 else 3 if x > 2 else 0)
# Перекодирование колонки 'OpenPorchSF' на 1 или 0
subm_df['OpenPorchSF'] = subm_df['OpenPorchSF'].apply(lambda x: 0 if x == 0 else 1)
# Перекодирование колонки 'WoodDeckSF' на 1 или 0
subm_df['WoodDeckSF'] = subm_df['WoodDeckSF'].apply(lambda x: 0 if x == 0 else 1)

# %%
# удаляем колонки
subm_df = subm_df.drop(columns=col_2_delete)
# one-hot encoding
subm_df = pd.get_dummies(subm_df, columns=col_2_encoding)

# Применяем StandartScaler: после его применения у всех колонок среднее станет равно 0, стандартное отклонение 1
ss_scaler = StandardScaler()
subm_df[col_2_normalize] = ss_scaler.fit_transform(subm_df[col_2_normalize])

# %%
bsmt_qual_mapping = {'Ex': 5, 'Gd': 4, 'TA': 3, 'Fa': 2, 'Po': 1, 'NA': 0}
subm_df['BsmtQual'] = subm_df['BsmtQual'].map(bsmt_qual_mapping)
exter_qual_mapping = {'Ex': 5, 'Gd': 4, 'TA': 3, 'Fa': 2, 'Po': 1}
subm_df['ExterQual'] = subm_df['ExterQual'].map(exter_qual_mapping)
exter_cond_mapping = {'Ex': 5, 'Gd': 4, 'TA': 3, 'Fa': 2, 'Po': 1}
subm_df['ExterCond'] = subm_df['ExterCond'].map(exter_cond_mapping)
heating_qc_mapping = {'Ex': 5, 'Gd': 4, 'TA': 3, 'Fa': 2, 'Po': 1}
subm_df['HeatingQC'] = subm_df['HeatingQC'].map(heating_qc_mapping)
subm_df['LotFrontage']=subm_df['LotFrontage'].fillna(subm_df['LotFrontage'].mean())
subm_df['BsmtQual']=subm_df['BsmtQual'].fillna(subm_df['BsmtQual'].mode()[0])
subm_df.drop(['Street', 'Alley', 'Utilities', 'LandSlope', 'Condition2', 'RoofMatl', 'Neighborhood', 'Heating'], axis=1, inplace=True)


columns_to_transform = ['MSZoning', 'LotShape', 'LandContour', 'LotConfig', 'Condition1', 'BldgType',
                        'RoofStyle', 'MasVnrArea', 'BsmtCond', 'BsmtExposure', 'BsmtFinType2', 'BsmtFinSF2']
for col in columns_to_transform:
    most_frequent_value = subm_df[col].mode()[0]
    subm_df[col] = subm_df[col].apply(lambda x: 1 if x == most_frequent_value else 0)



columns_to_normalize = ['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
                        'YearBuilt', 'YearRemodAdd', 'ExterQual', 'ExterCond', 'BsmtFinSF1',
                        'BsmtUnfSF', 'TotalBsmtSF','BsmtQual','HeatingQC']

for col in columns_to_normalize:
    subm_df[col] = (subm_df[col] - subm_df[col].min()) / (subm_df[col].max() - subm_df[col].min())

columns_to_transform = ['HouseStyle', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'Foundation', 'BsmtFinType1']

for column in columns_to_transform:
    value_counts = df[column].value_counts()
    most_popular_value = value_counts.index[0]
    second_popular_value = value_counts.index[1]
    subm_df[column] = subm_df[column].apply(lambda x: 2 if x == most_popular_value else (1 if x == second_popular_value else 0))

# %%
subm_df.shape
# Out:
# (2919, 73)

# %%
X_train=subm_df.iloc[:1460,:]
X_test=subm_df.iloc[1460:,:]
# df_Test.drop(['SalePrice'],axis=1,inplace=True)
# X_train=df_Train.drop(['SalePrice'],axis=1)
# y_train=df_Train['SalePrice']

# %%
X_train.shape, X_test.shape
# Out:
# ((1460, 73), (1459, 73))

# %% [markdown]
# ### Модель

# %%
regressor=xgboost.XGBRegressor()
booster=['gbtree','gblinear']
base_score=[0.25,0.5,0.75,1]

# %%
n_estimators = [100, 200, 300]
max_depth = [2, 3, 5, 7]
booster=['gbtree','gblinear']
learning_rate=[0.05,0.1,0.15,0.20]
# min_child_weight=[1,2,3,4]

hyperparameter_grid = {
    'n_estimators': n_estimators,
    'max_depth':max_depth,
    'learning_rate':learning_rate,
    # 'min_child_weight':min_child_weight,
    'booster':booster,
    'base_score':base_score
    }

# %%
from sklearn.model_selection import RandomizedSearchCV
random_cv = RandomizedSearchCV(estimator=regressor,
            param_distributions=hyperparameter_grid,
            cv=5, n_iter=50,
            scoring = 'neg_mean_squared_error',
            n_jobs = -1,
            verbose = 5,
            return_train_score = True,
            random_state=42)

# %%
X_train.dtypes
# Out:
# Id               int64
# MSSubClass     float64
# MSZoning         int64
# LotFrontage    float64
# LotArea        float64
#                 ...
# YrSold_2006       bool
# YrSold_2007       bool
# YrSold_2008       bool
# YrSold_2009       bool
# YrSold_2010       bool
# Length: 73, dtype: object

# %%
X_train.dtypes.unique()
# Out:
# array([dtype('int64'), dtype('float64'), dtype('O'), dtype('bool')],
#       dtype=object)

# %%
# надо разобраться, так делать нельзя
X_train = X_train.select_dtypes(include = ['float64', 'int64', 'bool'])

# %%
random_cv.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [18:40:02] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 2/5] END base_score=0.75, booster=gblinear, learning_rate=0.15, max_depth=3, n_estimators=200;, score=(train=-1045539959.217, test=-1189062945.406) total time=   1.8s
# [18:40:04] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [18:40:04] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [18:40:04] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 4/5] END base_score=0.75, booster=gblinear, learning_rate=0.15, max_depth=3, n_estimators=200;, score=(train=-1135447671.711, test=-802723989.687) total time=   0.8s
# [CV 3/5] END base_score=0.75, booster=gblinear, learning_rate=0.15, max_depth=3, n_estimators=200;, score=(train=-1020588178.880, test=-1352317323.666) total time=   0.9s
# [18:40:05] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [18:40:06] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 5/5] END base_score=0.75, booster=gblinear, learning_rate=0.05, max_depth=7, n_estimators=200;, score=(train=-905331131.857, test=-2471629947.844) total time=   0.8s
# [18:40:06] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 4/5] END base_score=0.75, booster=gblinear, learning_rate=0.05, max_depth=7, n_estimators=200;, score=(train=-1224860202.431, test=-813236405.394) total time=   2.4s
# [18:40:07] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [18:40:07] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 1/5] END base_score=1, booster=gblinear, learning_rate=0.1, max_depth=5, n_estimators=200;, score=(train=-1173373490.570, test=-765727813.151) total time=   1.8s
# [18:40:07] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [18:40:08] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [18:40:08] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 2/5] END base_score=1, booster=gblinear, learning_rate=0.1, max_depth=5, n_estimators=200;, score=(train=-1066492006.581, test=-1183777815.552) total time=   1.7s
# [CV 3/5] END base_score=1, booster=gblinear, learning_rate=0.1, max_depth=5, n_estimators=200;, score=(train=-1040959087.404, test=-1375158868.848) total time=   1.5s
# [18:40:08] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 4/5] END base_score=1, booster=gblinear, learning_rate=0.1, max_depth=5, n_estimators=200;, score=(train=-1161026212.405, test=-796502085.223) total time=   0.9s
# [18:40:08] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 5/5] END base_score=0.75, booster=gblinear, learning_rate=0.15, max_depth=3, n_estimators=200;, score=(train=-846296241.560, test=-2396137685.313) total time=   1.0s
# [CV 5/5] END base_score=1, booster=gblinear, learning_rate=0.1, max_depth=5, n_estimators=200;, score=(train=-862127111.997, test=-2423090307.006) total time=   1.5s
# [CV 1/5] END base_score=0.75, booster=gblinear, learning_rate=0.05, max_depth=7, n_estimators=200;, score=(train=-1230239764.945, test=-800326939.480) total time=   1.7s
# [CV 1/5] END base_score=0.75, booster=gblinear, learning_rate=0.15, max_depth=3, n_estimators=200;, score=(train=-1152251896.967, test=-750821673.378) total time=   2.6s
# [CV 3/5] END base_score=0.75, booster=gblinear, learning_rate=0.05, max_depth=7, n_estimators=200;, score=(train=-1094622266.403, test=-1435175227.790) total time=   2.5s
# [18:40:10] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [18:40:11] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [18:40:11] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 2/5] END base_score=0.75, booster=gblinear, learning_rate=0.05, max_depth=7, n_estimators=200;, score=(train=-1125553233.843, test=-1183858266.040) total time=   1.8s
# [CV 1/5] END base_score=0.25, booster=gblinear, learning_rate=0.05, max_depth=5, n_estimators=300;, score=(train=-1195066236.751, test=-781929535.014) total time=   1.7s
# [18:40:12] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [18:40:12] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 2/5] END base_score=0.25, booster=gblinear, learning_rate=0.05, max_depth=5, n_estimators=300;, score=(train=-1089374967.233, test=-1182074197.171) total time=   3.2s
# [18:40:14] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 3/5] END base_score=0.25, booster=gblinear, learning_rate=0.05, max_depth=5, n_estimators=300;, score=(train=-1062073588.760, test=-1400869241.727) total time=   3.4s
# [18:40:16] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 4/5] END base_score=0.25, booster=gblinear, learning_rate=0.05, max_depth=5, n_estimators=300;, score=(train=-1186390652.242, test=-800656138.120) total time=   3.9s
# [18:40:17] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 5/5] END base_score=0.25, booster=gblinear, learning_rate=0.05, max_depth=5, n_estimators=300;, score=(train=-879603660.624, test=-2435801601.353) total time=   2.9s
# [18:40:17] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 1/5] END base_score=1, booster=gblinear, learning_rate=0.2, max_depth=2, n_estimators=100;, score=(train=-1179166609.960, test=-765336527.506) total time=   1.5s
# [18:40:18] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 2/5] END base_score=1, booster=gblinear, learning_rate=0.2, max_depth=2, n_estimators=100;, score=(train=-1070846855.509, test=-1194775449.604) total time=   1.4s
# [18:40:18] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 3/5] END base_score=1, booster=gblinear, learning_rate=0.2, max_depth=2, n_estimators=100;, score=(train=-1043889537.850, test=-1373489267.992) total time=   1.1s
# [CV 4/5] END base_score=1, booster=gbtree, learning_rate=0.2, max_depth=5, n_estimators=300;, score=(train=-317921.766, test=-609069934.703) total time=   8.6s
# [CV 5/5] END base_score=1, booster=gbtree, learning_rate=0.2, max_depth=5, n_estimators=300;, score=(train=-271770.666, test=-1251537774.491) total time=   8.3s
# [CV 4/5] END base_score=1, booster=gblinear, learning_rate=0.2, max_depth=2, n_estimators=100;, score=(train=-1164933296.511, test=-802767112.011) total time=   1.0s
# [CV 5/5] END base_score=1, booster=gblinear, learning_rate=0.2, max_depth=2, n_estimators=100;, score=(train=-865853704.160, test=-2455618995.409) total time=   1.0s
# [CV 1/5] END base_score=1, booster=gbtree, learning_rate=0.2, max_depth=5, n_estimators=300;, score=(train=-269520.633, test=-753273148.235) total time=  11.6s
# [CV 2/5] END base_score=0.25, booster=gbtree, learning_rate=0.15, max_depth=7, n_estimators=100;, score=(train=-3079287.958, test=-1599644025.333) total time=   3.1s
# [CV 3/5] END base_score=1, booster=gbtree, learning_rate=0.2, max_depth=5, n_estimators=300;, score=(train=-233823.956, test=-911374938.245) total time=  14.0s
# [CV 2/5] END base_score=0.5, booster=gbtree, learning_rate=0.1, max_depth=5, n_estimators=100;, score=(train=-66270639.161, test=-1473380475.940) total time=   2.4s
# [CV 5/5] END base_score=0.25, booster=gbtree, learning_rate=0.15, max_depth=7, n_estimators=100;, score=(train=-3813202.887, test=-1321065351.052) total time=   5.1s
# [CV 1/5] END base_score=0.5, booster=gbtree, learning_rate=0.1, max_depth=5, n_estimators=100;, score=(train=-59022508.822, test=-698408725.929) total time=   5.4s
# [18:40:26] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 3/5] END base_score=0.25, booster=gbtree, learning_rate=0.15, max_depth=7, n_estimators=100;, score=(train=-2956572.857, test=-813411627.361) total time=   7.6s
# [18:40:26] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 2/5] END base_score=1, booster=gbtree, learning_rate=0.2, max_depth=5, n_estimators=300;, score=(train=-209106.543, test=-1488031828.596) total time=  17.8s
# [18:40:26] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 1/5] END base_score=1, booster=gblinear, learning_rate=0.2, max_depth=3, n_estimators=100;, score=(train=-1179166609.960, test=-765336527.506) total time=   0.7s
# [18:40:26] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 4/5] END base_score=1, booster=gblinear, learning_rate=0.2, max_depth=3, n_estimators=100;, score=(train=-1164933296.511, test=-802767112.011) total time=   0.4s
# [CV 2/5] END base_score=1, booster=gblinear, learning_rate=0.2, max_depth=3, n_estimators=100;, score=(train=-1070846855.509, test=-1194775449.604) total time=   0.7s
# [18:40:27] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 5/5] END base_score=1, booster=gblinear, learning_rate=0.2, max_depth=3, n_estimators=100;, score=(train=-865853704.160, test=-2455618995.409) total time=   0.4s
# [CV 3/5] END base_score=0.5, booster=gbtree, learning_rate=0.1, max_depth=5, n_estimators=100;, score=(train=-60716822.695, test=-946298590.426) total time=   3.9s
# [CV 3/5] END base_score=1, booster=gblinear, learning_rate=0.2, max_depth=3, n_estimators=100;, score=(train=-1043889537.850, test=-1373489267.992) total time=   1.3s
# [CV 1/5] END base_score=0.25, booster=gbtree, learning_rate=0.15, max_depth=7, n_estimators=100;, score=(train=
},
#                    random_state=42, return_train_score=True,
#                    scoring='neg_mean_squared_error', verbose=5)

# %%
from sklearn.metrics import mean_squared_error
def get_score(model, X, y):
    model.fit(X, y.ravel())

    # Получаем предсказания на тестовых данных
    y_pred = model.predict(X)

    # Вычисляем среднеквадратическую ошибку (MSE)
    mse = mean_squared_error(y, y_pred)

    # Получаем корень из MSE, чтобы получить RMSE
    rmse = np.sqrt(mse)

    return f'Значение метрики RMSE: {rmse}'

# %%
get_score(random_cv, X_train, y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [18:48:00] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 1/5] END base_score=0.75, booster=gblinear, learning_rate=0.15, max_depth=3, n_estimators=200;, score=(train=-1152251896.967, test=-750821673.378) total time=   0.7s
# [18:48:00] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 5/5] END base_score=0.75, booster=gblinear, learning_rate=0.15, max_depth=3, n_estimators=200;, score=(train=-846296241.560, test=-2396137685.313) total time=   0.8s
# [18:48:01] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [18:48:02] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 2/5] END base_score=0.75, booster=gblinear, learning_rate=0.05, max_depth=7, n_estimators=200;, score=(train=-1125553233.843, test=-1183858266.040) total time=   1.2s
# [18:48:03] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 4/5] END base_score=0.75, booster=gblinear, learning_rate=0.15, max_depth=3, n_estimators=200;, score=(train=-1135447671.711, test=-802723989.687) total time=   0.7s
# [18:48:03] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 1/5] END base_score=1, booster=gblinear, learning_rate=0.1, max_depth=5, n_estimators=200;, score=(train=-1173373490.570, test=-765727813.151) total time=   0.9s
# [18:48:03] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 2/5] END base_score=1, booster=gblinear, learning_rate=0.1, max_depth=5, n_estimators=200;, score=(train=-1066492006.581, test=-1183777815.552) total time=   0.6s
# [18:48:04] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 3/5] END base_score=1, booster=gblinear, learning_rate=0.1, max_depth=5, n_estimators=200;, score=(train=-1040959087.404, test=-1375158868.848) total time=   0.7s
# [18:48:04] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 4/5] END base_score=1, booster=gblinear, learning_rate=0.1, max_depth=5, n_estimators=200;, score=(train=-1161026212.405, test=-796502085.223) total time=   0.6s
# [CV 5/5] END base_score=1, booster=gblinear, learning_rate=0.1, max_depth=5, n_estimators=200;, score=(train=-862127111.997, test=-2423090307.006) total time=   0.7s
# [18:48:06] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 2/5] END base_score=0.75, booster=gblinear, learning_rate=0.15, max_depth=3, n_estimators=200;, score=(train=-1045539959.217, test=-1189062945.406) total time=   0.7s
# [18:48:08] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [18:48:10] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 1/5] END base_score=1, booster=gbtree, learning_rate=0.2, max_depth=5, n_estimators=300;, score=(train=-269520.633, test=-753273148.235) total time=   5.5s
# [CV 3/5] END base_score=0.75, booster=gblinear, learning_rate=0.05, max_depth=7, n_estimators=200;, score=(train=-1094622266.403, test=-1435175227.790) total time=   0.7s
# [CV 3/5] END base_score=0.75, booster=gblinear, learning_rate=0.15, max_depth=3, n_estimators=200;, score=(train=-1020588178.880, test=-1352317323.666) total time=   2.7s
# [18:48:11] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [18:48:11] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [18:48:11] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [18:48:13] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 3/5] END base_score=1, booster=gbtree, learning_rate=0.2, max_depth=5, n_estimators=300;, score=(train=-233823.956, test=-911374938.245) total time=   5.8s
# [CV 1/5] END base_score=0.75, booster=gblinear, learning_rate=0.05, max_depth=7, n_estimators=200;, score=(train=-1230239764.945, test=-800326939.480) total time=   1.9s
# [18:48:13] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 5/5] END base_score=0.75, booster=gblinear, learning_rate=0.05, max_depth=7, n_estimators=200;, score=(train=-905331131.857, test=-2471629947.844) total time=   2.2s
# [18:48:14] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 2/5] END base_score=0.25, booster=gblinear, learning_rate=0.05, max_depth=5, n_estimators=300;, score=(train=-1089374967.233, test=-1182074197.171) total time=   1.0s
# [18:48:14] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [18:48:14] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 5/5] END base_score=0.25, booster=gblinear, learning_rate=0.05, max_depth=5, n_estimators=300;, score=(train=-879603660.624, test=-2435801601.353) total time=   1.0s
# [18:48:15] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 1/5] END base_score=0.25, booster=gblinear, learning_rate=0.05, max_depth=5, n_estimators=300;, score=(train=-1195066236.751, test=-781929535.014) total time=   4.7s
# [CV 1/5] END base_score=1, booster=gblinear, learning_rate=0.2, max_depth=2, n_estimators=100;, score=(train=-1179166609.960, test=-765336527.506) total time=   0.7s
# [18:48:16] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [18:48:16] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 5/5] END base_score=1, booster=gbtree, learning_rate=0.2, max_depth=5, n_estimators=300;, score=(train=-271770.666, test=-1251537774.491) total time=   5.3s
# [18:48:16] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 4/5] END base_score=0.75, booster=gblinear, learning_rate=0.05, max_depth=7, n_estimators=200;, score=(train=-1224860202.431, test=-813236405.394) total time=   3.3s
# [CV 4/5] END base_score=1, booster=gblinear, learning_rate=0.2, max_depth=2, n_estimators=100;, score=(train=-1164933296.511, test=-802767112.011) total time=   0.4s
# [18:48:16] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 3/5] END base_score=0.25, booster=gblinear, learning_rate=0.05, max_depth=5, n_estimators=300;, score=(train=-1062073588.760, test=-1400869241.727) total time=   2.9s
# [CV 3/5] END base_score=1, booster=gblinear, learning_rate=0.2, max_depth=2, n_estimators=100;, score=(train=-1043889537.850, test=-1373489267.992) total time=   1.1s
# [CV 2/5] END base_score=1, booster=gblinear, learning_rate=0.2, max_depth=2, n_estimators=100;, score=(train=-1070846855.509, test=-1194775449.604) total time=   1.5s
# [CV 5/5] END base_score=1, booster=gblinear, learning_rate=0.2, max_depth=2, n_estimators=100;, score=(train=-865853704.160, test=-2455618995.409) total time=   0.9s
# [CV 2/5] END base_score=1, booster=gbtree, learning_rate=0.2, max_depth=5, n_estimators=300;, score=(train=-209106.543, test=-1488031828.596) total time=  12.9s
# [CV 4/5] END base_score=0.25, booster=gblinear, learning_rate=0.05, max_depth=5, n_estimators=300;, score=(train=-1186390652.242, test=-800656138.120) total time=   4.4s
# [CV 1/5] END base_score=0.25, booster=gbtree, learning_rate=0.15, max_depth=7, n_estimators=100;, score=(train=-3315610.916, test=-772468324.638) total time=   4.9s
# [CV 2/5] END base_score=0.5, booster=gbtree, learning_rate=0.1, max_depth=5, n_estimators=100;, score=(train=-66270639.161, test=-1473380475.940) total time=   3.6s
# [CV 5/5] END base_score=0.25, booster=gbtree, learning_rate=0.15, max_depth=7, n_estimators=100;, score=(train=-3813202.887, test=-1321065351.052) total time=   4.8s
# [CV 1/5] END base_score=0.5, booster=gbtree, learning_rate=0.1, max_depth=5, n_estimators=100;, score=(train=-59022508.822, test=-698408725.929) total time=   4.7s
# [18:48:23] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 1/5] END base_score=1, booster=gblinear, learning_rate=0.2, max_depth=3, n_estimators=100;, score=(train=-1179166609.960, test=-765336527.506) total time=   0.8s
# [18:48:24] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 2/5] END base_score=0.25, booster=gbtree, learning_rate=0.15, max_depth=7, n_estimators=100;, score=(train=-3079287.958, test=-1599644025.333) total time=   7.4s
# [18:48:24] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 4/5] END base_score=0.25, booster=gbtree, learning_rate=0.15, max_depth=7, n_estimators=100;, score=(train=-2723640.038, test=-726556906.866) total time=   7.5s
# [18:48:25] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 3/5] END base_score=0.25, booster=gbtree, learning_rate=0.15, max_depth=7, n_estimators=100;, score=(train=-2956572.857, test=-813411627.361) total time=   7.8s
# [18:48:25] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 3/5] END base_score=1, booster=gblinear, learning_rate=0.2, max_depth=3, n_estimators=100;, score=(train=-1043889537.850, test=-1373489267.992) total time=   1.1s
# [CV 4/5] END base_score=0.5, booster=gbtree, learning_rate=0.1, max_depth=5, n_estimators=100;, score=(train=-64363026.903, test=-597515856.145) total time=   3.2s
# [CV 2/5] END base_score=1, booster=gblinear, learning_rate=0.2, max_depth=3, n_estimators=100;, score=(train=-1070846855.509, test=-1194775449.604) total time=   1.3s
# [CV 4/5] END base_score=1, booster=gblinear, learning_rate=0.2, max_depth=3, n_estimators=100;, score=(train=-1164933296.511, test=-802767112.011) total time=   0.5s
# [CV 3/5] END base_score=0.5, booster=gbtree, learning_rate=0.1, max_depth=5, n_estimators=100;, score=(train=-60716822.695, test=-946298590.426) total time=   3.8s
# [CV 5/5] END base_score=1, booster=gblinear, learning_rate=0.2, max_depth=3, n_estimators=100;, score=(train=-865853704.160, test=-2455618995.409) total time=   0.8s
# [18:48:26] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 4/5] END base_score=1, booster=gbtree, learning_rate=0.2, max_depth=5, n_estimators
# [CV 5/5] END base_score=0.25, booster=gbtree, learning_rate=0.15, max_depth=5, n_estimators=200;, score=(train=-7440072.449, test=-1320394503.487) total time=   3.4s
# [18:50:12] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 1/5] END base_score=0.25, booster=gblinear, learning_rate=0.15, max_depth=3, n_estimators=300;, score=(train=-1138443352.337, test=-742738371.469) total time=   1.4s
# [18:50:14] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 1/5] END base_score=0.25, booster=gbtree, learning_rate=0.15, max_depth=5, n_estimators=200;, score=(train=-6419919.387, test=-643323201.660) total time=   9.0s
# [18:50:14] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 2/5] END base_score=0.25, booster=gbtree, learning_rate=0.1, max_depth=7, n_estimators=200;, score=(train=-783014.357, test=-1460952540.551) total time=  13.8s
# [18:50:15] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 2/5] END base_score=0.25, booster=gblinear, learning_rate=0.15, max_depth=3, n_estimators=300;, score=(train=-1033023896.290, test=-1187307944.327) total time=   1.1s
# [18:50:15] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 2/5] END base_score=0.25, booster=gbtree, learning_rate=0.15, max_depth=5, n_estimators=200;, score=(train=-6359895.382, test=-1413543169.337) total time=   9.9s
# [18:50:16] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 5/5] END base_score=0.25, booster=gblinear, learning_rate=0.15, max_depth=3, n_estimators=300;, score=(train=-836533129.343, test=-2370505137.963) total time=   1.2s
# [18:50:16] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 5/5] END base_score=0.25, booster=gbtree, learning_rate=0.1, max_depth=7, n_estimators=200;, score=(train=-1377028.103, test=-1178407481.137) total time=  12.0s
# [18:50:17] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 2/5] END base_score=0.25, booster=gblinear, learning_rate=0.2, max_depth=5, n_estimators=100;, score=(train=-1070846729.311, test=-1194775372.520) total time=   0.4s
# [18:50:17] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 3/5] END base_score=0.25, booster=gbtree, learning_rate=0.15, max_depth=5, n_estimators=200;, score=(train=-4397835.050, test=-912131467.068) total time=  10.4s
# [18:50:17] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 4/5] END base_score=0.25, booster=gblinear, learning_rate=0.2, max_depth=5, n_estimators=100;, score=(train=-1164933362.548, test=-802767175.347) total time=   0.4s
# [18:50:17] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 1/5] END base_score=0.25, booster=gblinear, learning_rate=0.2, max_depth=5, n_estimators=100;, score=(train=-1179166823.423, test=-765336426.453) total time=   1.4s
# [18:50:17] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 3/5] END base_score=0.25, booster=gblinear, learning_rate=0.2, max_depth=5, n_estimators=100;, score=(train=-1043889567.717, test=-1373489516.450) total time=   0.9s
# [18:50:17] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 3/5] END base_score=0.25, booster=gblinear, learning_rate=0.15, max_depth=3, n_estimators=300;, score=(train=-1007828469.430, test=-1343075974.289) total time=   3.3s
# [18:50:18] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 2/5] END base_score=0.25, booster=gblinear, learning_rate=0.05, max_depth=7, n_estimators=100;, score=(train=-1209663926.749, test=-1203544379.834) total time=   0.4s
# [18:50:18] WARNING: ../src/learner.cc:767:
# Parameters: { "max_depth" } are not used.
#
# [CV 4/5] END base_score=0.25, booster=gbtree, learning_rate=0.1, max_depth=7, n_estimators=200;, score=(train=-602161.790, test=-642291192.660) total time=  14.0s
# [CV 5/5] END base_score=0.25, booster=gblinear, learning_rate=0.05, max_depth=7, n_estimators=100;, score=(train=-963586934.445, test=-2535366923.280) total time=   0.4s
# [CV 5/5] END base_score=0.25, booster=gblinear, learning_rate=0.2, max_depth=5, n_estimators=100;, score=(train=-865853992.847, test=-2455620124.359) total time=   1.2s
# [CV 4/5] END base_score=0.25, booster=gblinear, learning_rate=0.15, max_depth=3, n_estimators=300;, score=(train=-1118938957.911, test=-812753863.556) total time=   3.6s
# [CV 1/5] END base_score=0.25, booster=gblinear, learning_rate=0.05, max_depth=7, n_estimators=100;, score=(train=-1310278274.390, test=-851074335.121) total time=   1.1s
# [CV 4/5] END base_score=0.25, booster=gblinear, learning_rate=0.05, max_depth=7, n_estimators=100;, score=(train=-1305961059.333, test=-864274014.719) total time=   0.9s
# [CV 3/5] END base_score=0.25, booster=gblinear, learning_rate=0.05, max_depth=7, n_estimators=100;, score=(train=-1167008754.320, test=-1503049793.942) total time=   1.1s
# [CV 4/5] END base_score=0.25, booster=gbtree, learning_rate=0.15, max_depth=5, n_estimators=200;, score=(train=-7050623.717, test=-608657226.629) total time=  11.2s
# 'Значение метрики RMSE: 16191.099143244117'

# %%
# df_last_40 = subm_df[subm_cols[40:]].copy()
# # удаляем колонки
# df_last_40 = df_last_40.drop(columns=col_2_delete)

# # one-hot encoding
# df_last_40 = pd.get_dummies(df_last_40, columns=col_2_encoding)

# # Применяем StandartScaler: после его применения у всех колонок среднее станет равно 0, стандартное отклонение 1
# ss_scaler = StandardScaler()
# df_last_40[col_2_normalize] = ss_scaler.fit_transform(df_last_40[col_2_normalize])

# %%
# df_last_40.shape

# %%
# df_last_40.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8);

# %%
# Сохраняем DataFrame в CSV-файл
# df_last_40.to_csv('subm_df_last_40.csv', index=False)

# %%
# df_num = df.select_dtypes(include = ['float64', 'int64'])
# df_num.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8);

# %%
# def res_2_csv(id_column, predictions_column, file_name='submission.csv'):
#     # Создаем DataFrame из переданных столбцов
#     df = pd.DataFrame({ 'Id': id_column, 'SalePrice': predictions_column })
#     # Сохраняем DataFrame в CSV-файл
#     df.to_csv(file_name, index=False)

# # res_2_csv(test['Id'], y_hat)
